# %%
import re
output_dir = "\analysis"

# %%
# Read the log.mv file and print its contents
with open('log.yPlus', 'r') as file:
    log_contents = file.read()

print(log_contents)
# Out:
# /*---------------------------------------------------------------------------*\
# | =========                 |                                                 |
# | \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox           |
# |  \\    /   O peration     | Version:  2406                                  |
# |   \\  /    A nd           | Website:  www.openfoam.com                      |
# |    \\/     M anipulation  |                                                 |
# \*---------------------------------------------------------------------------*/
# Build  : 630d60de3b-20240620 OPENFOAM=2406 version=v2406
# Arch   : "LSB;label=32;scalar=64"
# Exec   : overInterDyMFoam -postProcess -func yPlus -parallel
# Date   : Feb 07 2025
# Time   : 13:58:03
# Host   : Coastal-song
# PID    : 1150
# I/O    : uncollated
# Case   : /home/song/OpenFOAM/song-v2406/run/pukyung_0124_8/background
# nProcs : 32
# Hosts  :
# (
#     (Coastal-song 32)
# )
# Pstream initialized with:
#     floatTransfer      : false
#     maxCommsSize       : 0
#     nProcsSimpleSum    : 0
#     nonBlockingExchange: 0 (tuning: 0)
#     exchange algorithm : 0
#     commsType          : nonBlocking
#     polling iterations : 0
# trapFpe: Floating point exception trapping enabled (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 5, maxFileModificationPolls 20)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# Create mesh for time = 0
#
#
# PIMPLE: no residual control data found. Calculations will employ 2 corrector loops
#
# Time = 0
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# inverseDistance : detected 2 mesh regions
#     zone:0 nCells:12000  voxels:(100 400 1) bb:(-2 -8.6 -0.1) (2 7 0.1)
#     zone:1 nCells:378  voxels:(100 400 1) bb:(-2 -8.6 -0.1) (2 7 0.1)
# Overset analysis : nCells : 12378
#     calculated   : 11464
#     interpolated : 256 (from local:232  mixed local/remote:24  remote:0)
#     hole         : 658
#
# Creating cellMask field to block out hole cells
#
# --> FOAM Warning :
#     From bool Foam::oversetPolyPatch::master() const
#     in file oversetPolyPatch/oversetPolyPatch.C at line 145
#     The master overset patch is not the first patch. Generally the first patch should be an overset patch to guarantee consistent operation.
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 370.0828, max = 5477.226, average = 1136.154
#     patch bottom_1 y+ : min = 5477.226, max = 5477.226, average = 5477.226
#     patch right_3 y+ : min = 370.0828, max = 5477.226, average = 1136.154
#     patch bottom_3 y+ : min = 5477.226, max = 5477.226, average = 5477.226
#     patch left_4 y+ : min = 5477.226, max = 5477.226, average = 5477.226
#     patch right_4 y+ : min = 5477.226, max = 5477.226, average = 5477.226
#     patch bottom_4 y+ : min = 5477.226, max = 5477.226, average = 5477.226
#     patch movingObject y+ : min = 5477.226, max = 5477.226, average = 5477.226
#
# Time = 0.0005
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 370.0469, max = 5476.745, average = 1136.05
#     patch bottom_1 y+ : min = 5476.682, max = 5488.492, average = 5477.801
#     patch right_3 y+ : min = 370.0469, max = 5476.745, average = 1136.05
#     patch bottom_3 y+ : min = 5476.682, max = 5488.492, average = 5477.801
#     patch left_4 y+ : min = 5476.677, max = 5501.818, average = 5482.909
#     patch right_4 y+ : min = 5476.677, max = 5501.818, average = 5482.909
#     patch bottom_4 y+ : min = 5476.677, max = 5476.677, average = 5476.677
#     patch movingObject y+ : min = 5481.961, max = 5522.532, average = 5498.05
#
# Time = 0.001
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 370.0106, max = 5476.277, average = 1135.946
#     patch bottom_1 y+ : min = 5476.139, max = 5500.441, average = 5478.371
#     patch right_3 y+ : min = 370.0106, max = 5476.277, average = 1135.946
#     patch bottom_3 y+ : min = 5476.139, max = 5500.444, average = 5478.371
#     patch left_4 y+ : min = 5476.128, max = 5531.762, average = 5488.611
#     patch right_4 y+ : min = 5476.128, max = 5531.762, average = 5488.61
#     patch bottom_4 y+ : min = 5476.128, max = 5476.128, average = 5476.128
#     patch movingObject y+ : min = 5485.162, max = 5580.228, average = 5519.049
#
# Time = 0.0015
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 369.9747, max = 5475.812, average = 1135.843
#     patch bottom_1 y+ : min = 5475.596, max = 5513.042, average = 5478.936
#     patch right_3 y+ : min = 369.9747, max = 5475.812, average = 1135.843
#     patch bottom_3 y+ : min = 5475.596, max = 5513.045, average = 5478.936
#     patch left_4 y+ : min = 5475.579, max = 5567.629, average = 5494.311
#     patch right_4 y+ : min = 5475.579, max = 5567.629, average = 5494.311
#     patch bottom_4 y+ : min = 5475.579, max = 5475.58, average = 5475.579
#     patch movingObject y+ : min = 5487.428, max = 5644.509, average = 5540.202
#
# Time = 0.002
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 369.9391, max = 5475.347, average = 1135.739
#     patch bottom_1 y+ : min = 5475.053, max = 5526.282, average = 5479.508
#     patch right_3 y+ : min = 369.9391, max = 5475.347, average = 1135.739
#     patch bottom_3 y+ : min = 5475.053, max = 5526.287, average = 5479.508
#     patch left_4 y+ : min = 5475.03, max = 5608.898, average = 5500.089
#     patch right_4 y+ : min = 5475.03, max = 5608.896, average = 5500.088
#     patch bottom_4 y+ : min = 5475.03, max = 5475.032, average = 5475.03
#     patch movingObject y+ : min = 5489.156, max = 5709.537, average = 5561.58
#
# Time = 0.0025
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 369.9034, max = 5474.881, average = 1135.636
#     patch bottom_1 y+ : min = 5474.51, max = 5540.08, average = 5480.084
#     patch right_3 y+ : min = 369.9034, max = 5474.881, average = 1135.636
#     patch bottom_3 y+ : min = 5474.51, max = 5540.091, average = 5480.085
#     patch left_4 y+ : min = 5474.481, max = 5654.773, average = 5505.944
#     patch right_4 y+ : min = 5474.481, max = 5654.771, average = 5505.944
#     patch bottom_4 y+ : min = 5474.481, max = 5474.483, average = 5474.481
#     patch movingObject y+ : min = 5490.508, max = 5772.141, average = 5583.118
#
# Time = 0.003
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 369.8674, max = 5474.416, average = 1135.533
#     patch bottom_1 y+ : min = 5473.968, max = 5554.366, average = 5480.664
#     patch right_3 y+ : min = 369.8675, max = 5474.416, average = 1135.533
#     patch bottom_3 y+ : min = 5473.968, max = 5554.377, average = 5480.665
#     patch left_4 y+ : min = 5473.931, max = 5704.448, average = 5511.873
#     patch right_4 y+ : min = 5473.931, max = 5704.446, average = 5511.872
#     patch bottom_4 y+ : min = 5473.931, max = 5473.935, average = 5473.932
#     patch movingObject y+ : min = 5491.565, max = 5840.844, average = 5604.758
#
# Time = 0.0035
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 369.8312, max = 5473.95, average = 1135.429
#     patch bottom_1 y+ : min = 5473.425, max = 5569.067, average = 5481.245
#     patch right_3 y+ : min = 369.8312, max = 5473.95, average = 1135.429
#     patch bottom_3 y+ : min = 5473.425, max = 5569.083, average = 5481.247
#     patch left_4 y+ : min = 5473.382, max = 5757.145, average = 5517.87
#     patch right_4 y+ : min = 5473.382, max = 5757.14, average = 5517.869
#     patch bottom_4 y+ : min = 5473.382, max = 5473.387, average = 5473.383
#     patch movingObject y+ : min = 5492.387, max = 5926.558, average = 5626.454
#
# Time = 0.004
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 369.7947, max = 5473.484, average = 1135.325
#     patch bottom_1 y+ : min = 5472.883, max = 5584.125, average = 5481.827
#     patch right_3 y+ : min = 369.7947, max = 5473.484, average = 1135.325
#     patch bottom_3 y+ : min = 5472.883, max = 5584.146, average = 5481.829
#     patch left_4 y+ : min = 5472.833, max = 5812.16, average = 5523.93
#     patch right_4 y+ : min = 5472.833, max = 5812.152, average = 5523.929
#     patch bottom_4 y+ : min = 5472.833, max = 5472.839, average = 5472.833
#     patch movingObject y+ : min = 5493.005, max = 6014.51, average = 5648.175
#
# Time = 0.0045
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 369.7627, max = 5473.023, average = 1135.225
#     patch bottom_1 y+ : min = 5472.341, max = 5599.407, average = 5482.437
#     patch right_3 y+ : min = 369.7627, max = 5473.023, average = 1135.225
#     patch bottom_3 y+ : min = 5472.341, max = 5599.431, average = 5482.439
#     patch left_4 y+ : min = 5472.283, max = 5868.995, average = 5530.104
#     patch right_4 y+ : min = 5472.283, max = 5868.979, average = 5530.103
#     patch bottom_4 y+ : min = 5472.283, max = 5472.291, average = 5472.284
#     patch movingObject y+ : min = 5493.458, max = 6105.129, average = 5669.983
#
# Time = 0.005
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 369.731, max = 5472.564, average = 1135.125
#     patch bottom_1 y+ : min = 5471.799, max = 5614.854, average = 5483.046
#     patch right_3 y+ : min = 369.731, max = 5472.564, average = 1135.125
#     patch bottom_3 y+ : min = 5471.799, max = 5614.88, average = 5483.048
#     patch left_4 y+ : min = 5471.734, max = 5926.814, average = 5536.326
#     patch right_4 y+ : min = 5471.734, max = 5926.796, average = 5536.325
#     patch bottom_4 y+ : min = 5471.734, max = 5471.744, average = 5471.735
#     patch movingObject y+ : min = 5493.805, max = 6195.621, average = 5691.773
#
# Time = 0.0055
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 369.6993, max = 5472.105, average = 1135.026
#     patch bottom_1 y+ : min = 5471.258, max = 5630.452, average = 5483.652
#     patch right_3 y+ : min = 369.6993, max = 5472.106, average = 1135.026
#     patch bottom_3 y+ : min = 5471.258, max = 5630.481, average = 5483.655
#     patch left_4 y+ : min = 5471.184, max = 5985.202, average = 5542.597
#     patch right_4 y+ : min = 5471.184, max = 5985.179, average = 5542.596
#     patch bottom_4 y+ : min = 5471.184, max = 5471.196, average = 5471.186
#     patch movingObject y+ : min = 5494.048, max = 6284.996, average = 5713.55
#
# Time = 0.006
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 369.6678, max = 5471.647, average = 1134.926
#     patch bottom_1 y+ : min = 5470.717, max = 5646.196, average = 5484.257
#     patch right_3 y+ : min = 369.6678, max = 5471.648, average = 1134.926
#     patch bottom_3 y+ : min = 5470.717, max = 5646.228, average = 5484.259
#     patch left_4 y+ : min = 5470.635, max = 6043.852, average = 5548.919
#     patch right_4 y+ : min = 5470.635, max = 6043.825, average = 5548.918
#     patch bottom_4 y+ : min = 5470.635, max = 5470.649, average = 5470.636
#     patch movingObject y+ : min = 5494.198, max = 6372.502, average = 5735.331
#
# Time = 0.0065
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 369.6367, max = 5471.191, average = 1134.827
#     patch bottom_1 y+ : min = 5470.176, max = 5662.076, average = 5484.861
#     patch right_3 y+ : min = 369.6367, max = 5471.191, average = 1134.827
#     patch bottom_3 y+ : min = 5470.176, max = 5662.111, average = 5484.864
#     patch left_4 y+ : min = 5470.085, max = 6102.556, average = 5555.297
#     patch right_4 y+ : min = 5470.085, max = 6102.527, average = 5555.295
#     patch bottom_4 y+ : min = 5470.085, max = 5470.101, average = 5470.087
#     patch movingObject y+ : min = 5494.255, max = 6457.621, average = 5757.137
#
# Time = 0.007
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 369.6064, max = 5470.736, average = 1134.729
#     patch bottom_1 y+ : min = 5469.635, max = 5678.103, average = 5485.469
#     patch right_3 y+ : min = 369.6064, max = 5470.736, average = 1134.729
#     patch bottom_3 y+ : min = 5469.635, max = 5678.14, average = 5485.471
#     patch left_4 y+ : min = 5469.535, max = 6161.226, average = 5561.734
#     patch right_4 y+ : min = 5469.535, max = 6161.192, average = 5561.733
#     patch bottom_4 y+ : min = 5469.535, max = 5469.554, average = 5469.537
#     patch movingObject y+ : min = 5494.228, max = 6540.08, average = 5778.986
#
# Time = 0.0075
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 369.5774, max = 5470.283, average = 1134.632
#     patch bottom_1 y+ : min = 5469.094, max = 5694.31, average = 5486.085
#     patch right_3 y+ : min = 369.5774, max = 5470.283, average = 1134.632
#     patch bottom_3 y+ : min = 5469.094, max = 5694.347, average = 5486.088
#     patch left_4 y+ : min = 5468.986, max = 6219.946, average = 5568.242
#     patch right_4 y+ : min = 5468.986, max = 6219.912, average = 5568.24
#     patch bottom_4 y+ : min = 5468.986, max = 5469.007, average = 5468.988
#     patch movingObject y+ : min = 5494.121, max = 6619.884, average = 5800.908
#
# Time = 0.008
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 369.5407, max = 5469.829, average = 1134.53
#     patch bottom_1 y+ : min = 5468.551, max = 5710.824, average = 5486.698
#     patch right_3 y+ : min = 369.5407, max = 5469.829, average = 1134.53
#     patch bottom_3 y+ : min = 5468.551, max = 5710.863, average = 5486.701
#     patch left_4 y+ : min = 5468.436, max = 6279.06, average = 5574.839
#     patch right_4 y+ : min = 5468.436, max = 6279.027, average = 5574.837
#     patch bottom_4 y+ : min = 5468.436, max = 5468.46, average = 5468.438
#     patch movingObject y+ : min = 5493.911, max = 6698.434, average = 5823.016
#
# Time = 0.0085
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 369.504, max = 5469.374, average = 1134.427
#     patch bottom_1 y+ : min = 5468.003, max = 5727.117, average = 5487.288
#     patch right_3 y+ : min = 369.504, max = 5469.374, average = 1134.427
#     patch bottom_3 y+ : min = 5468.003, max = 5727.156, average = 5487.291
#     patch left_4 y+ : min = 5467.886, max = 6337.034, average = 5581.445
#     patch right_4 y+ : min = 5467.886, max = 6336.999, average = 5581.443
#     patch bottom_4 y+ : min = 5467.886, max = 5467.913, average = 5467.889
#     patch movingObject y+ : min = 5493.589, max = 6772.739, average = 5845.053
#
# Time = 0.009
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 369.4689, max = 5468.917, average = 1134.324
#     patch bottom_1 y+ : min = 5467.454, max = 5743.129, average = 5487.848
#     patch right_3 y+ : min = 369.4689, max = 5468.917, average = 1134.324
#     patch bottom_3 y+ : min = 5467.455, max = 5743.171, average = 5487.851
#     patch left_4 y+ : min = 5467.336, max = 6393.032, average = 5588.029
#     patch right_4 y+ : min = 5467.336, max = 6392.997, average = 5588.027
#     patch bottom_4 y+ : min = 5467.336, max = 5467.366, average = 5467.339
#     patch movingObject y+ : min = 5493.125, max = 6842.261, average = 5866.97
#
# Time = 0.0095
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 369.4347, max = 5468.459, average = 1134.221
#     patch bottom_1 y+ : min = 5466.905, max = 5758.924, average = 5488.384
#     patch right_3 y+ : min = 369.4347, max = 5468.459, average = 1134.221
#     patch bottom_3 y+ : min = 5466.905, max = 5758.966, average = 5488.387
#     patch left_4 y+ : min = 5466.786, max = 6446.655, average = 5594.602
#     patch right_4 y+ : min = 5466.786, max = 6446.615, average = 5594.599
#     patch bottom_4 y+ : min = 5466.786, max = 5466.819, average = 5466.789
#     patch movingObject y+ : min = 5492.527, max = 6907.246, average = 5888.811
#
# Time = 0.01
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 369.4011, max = 5468, average = 1134.118
#     patch bottom_1 y+ : min = 5466.355, max = 5774.505, average = 5488.9
#     patch right_3 y+ : min = 369.4011, max = 5468, average = 1134.118
#     patch bottom_3 y+ : min = 5466.355, max = 5774.549, average = 5488.903
#     patch left_4 y+ : min = 5466.236, max = 6497.585, average = 5601.169
#     patch right_4 y+ : min = 5466.236, max = 6497.543, average = 5601.167
#     patch bottom_4 y+ : min = 5466.236, max = 5466.273, average = 5466.24
#     patch movingObject y+ : min = 5491.811, max = 6967.694, average = 5910.604
#
# Time = 0.0105
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 369.3679, max = 5467.54, average = 1134.015
#     patch bottom_1 y+ : min = 5465.804, max = 5789.86, average = 5489.399
#     patch right_3 y+ : min = 369.3679, max = 5467.541, average = 1134.015
#     patch bottom_3 y+ : min = 5465.804, max = 5789.904, average = 5489.402
#     patch left_4 y+ : min = 5465.686, max = 6545.523, average = 5607.728
#     patch right_4 y+ : min = 5465.686, max = 6545.477, average = 5607.725
#     patch bottom_4 y+ : min = 5465.686, max = 5465.726, average = 5465.69
#     patch movingObject y+ : min = 5490.986, max = 7022.948, average = 5932.347
#
# Time = 0.011
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 369.335, max = 5467.081, average = 1133.912
#     patch bottom_1 y+ : min = 5465.253, max = 5804.968, average = 5489.881
#     patch right_3 y+ : min = 369.335, max = 5467.082, average = 1133.912
#     patch bottom_3 y+ : min = 5465.253, max = 5805.012, average = 5489.884
#     patch left_4 y+ : min = 5465.136, max = 6590.277, average = 5614.273
#     patch right_4 y+ : min = 5465.136, max = 6590.225, average = 5614.27
#     patch bottom_4 y+ : min = 5465.136, max = 5465.18, average = 5465.14
#     patch movingObject y+ : min = 5490.068, max = 7072.524, average = 5954.035
#
# Time = 0.0115
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 369.3021, max = 5466.622, average = 1133.81
#     patch bottom_1 y+ : min = 5464.701, max = 5819.807, average = 5490.347
#     patch right_3 y+ : min = 369.3021, max = 5466.623, average = 1133.81
#     patch bottom_3 y+ : min = 5464.701, max = 5819.851, average = 5490.35
#     patch left_4 y+ : min = 5464.586, max = 6631.744, average = 5620.802
#     patch right_4 y+ : min = 5464.586, max = 6631.688, average = 5620.799
#     patch bottom_4 y+ : min = 5464.586, max = 5464.633, average = 5464.59
#     patch movingObject y+ : min = 5489.065, max = 7116.164, average = 5975.67
#
# Time = 0.012
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 369.2691, max = 5466.164, average = 1133.707
#     patch bottom_1 y+ : min = 5464.148, max = 5834.364, average = 5490.797
#     patch right_3 y+ : min = 369.2691, max = 5466.165, average = 1133.707
#     patch bottom_3 y+ : min = 5464.148, max = 5834.407, average = 5490.801
#     patch left_4 y+ : min = 5464.035, max = 6669.896, average = 5627.312
#     patch right_4 y+ : min = 5464.035, max = 6669.835, average = 5627.309
#     patch bottom_4 y+ : min = 5464.035, max = 5464.087, average = 5464.041
#     patch movingObject y+ : min = 5487.989, max = 7153.808, average = 5997.254
#
# Time = 0.0125
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 369.2333, max = 5465.71, average = 1133.604
#     patch bottom_1 y+ : min = 5463.594, max = 5847.995, average = 5491.23
#     patch right_3 y+ : min = 369.2334, max = 5465.71, average = 1133.604
#     patch bottom_3 y+ : min = 5463.594, max = 5848.041, average = 5491.233
#     patch left_4 y+ : min = 5463.485, max = 6704.65, average = 5633.793
#     patch right_4 y+ : min = 5463.485, max = 6704.585, average = 5633.79
#     patch bottom_4 y+ : min = 5463.485, max = 5463.541, average = 5463.491
#     patch movingObject y+ : min = 5486.819, max = 7185.855, average = 6018.836
#
# Time = 0.013
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 369.1967, max = 5465.258, average = 1133.502
#     patch bottom_1 y+ : min = 5463.04, max = 5861.322, average = 5491.651
#     patch right_3 y+ : min = 369.1967, max = 5465.258, average = 1133.502
#     patch bottom_3 y+ : min = 5463.04, max = 5861.366, average = 5491.654
#     patch left_4 y+ : min = 5462.935, max = 6736.925, average = 5640.276
#     patch right_4 y+ : min = 5462.935, max = 6736.856, average = 5640.272
#     patch bottom_4 y+ : min = 5462.935, max = 5462.995, average = 5462.941
#     patch movingObject y+ : min = 5485.629, max = 7211.711, average = 6040.411
#
# Time = 0.0135
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 369.1596, max = 5464.807, average = 1133.4
#     patch bottom_1 y+ : min = 5462.484, max = 5874.324, average = 5492.059
#     patch right_3 y+ : min = 369.1597, max = 5464.808, average = 1133.4
#     patch bottom_3 y+ : min = 5462.484, max = 5874.37, average = 5492.062
#     patch left_4 y+ : min = 5462.385, max = 6766.684, average = 5646.758
#     patch right_4 y+ : min = 5462.385, max = 6766.611, average = 5646.754
#     patch bottom_4 y+ : min = 5462.384, max = 5462.45, average = 5462.391
#     patch movingObject y+ : min = 5484.407, max = 7231.751, average = 6061.981
#
# Time = 0.014
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 369.1233, max = 5464.359, average = 1133.299
#     patch bottom_1 y+ : min = 5461.928, max = 5887.006, average = 5492.455
#     patch right_3 y+ : min = 369.1233, max = 5464.359, average = 1133.299
#     patch bottom_3 y+ : min = 5461.928, max = 5887.052, average = 5492.459
#     patch left_4 y+ : min = 5461.834, max = 6793.873, average = 5653.234
#     patch right_4 y+ : min = 5461.834, max = 6793.798, average = 5653.23
#     patch bottom_4 y+ : min = 5461.834, max = 5461.904, average = 5461.841
#     patch movingObject y+ : min = 5483.143, max = 7246.465, average = 6083.547
#
# Time = 0.0145
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 369.0877, max = 5463.912, average = 1133.198
#     patch bottom_1 y+ : min = 5461.371, max = 5899.371, average = 5492.84
#     patch right_3 y+ : min = 369.0877, max = 5463.912, average = 1133.199
#     patch bottom_3 y+ : min = 5461.371, max = 5899.417, average = 5492.844
#     patch left_4 y+ : min = 5461.284, max = 6818.453, average = 5659.699
#     patch right_4 y+ : min = 5461.284, max = 6818.376, average = 5659.695
#     patch bottom_4 y+ : min = 5461.284, max = 5461.358, average = 5461.291
#     patch movingObject y+ : min = 5481.835, max = 7256.419, average = 6105.114
#
# Time = 0.015
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 369.053, max = 5463.466, average = 1133.099
#     patch bottom_1 y+ : min = 5460.813, max = 5911.424, average = 5493.216
#     patch right_3 y+ : min = 369.053, max = 5463.467, average = 1133.099
#     patch bottom_3 y+ : min = 5460.813, max = 5911.467, average = 5493.219
#     patch left_4 y+ : min = 5460.733, max = 6840.423, average = 5666.147
#     patch right_4 y+ : min = 5460.733, max = 6840.342, average = 5666.143
#     patch bottom_4 y+ : min = 5460.733, max = 5460.813, average = 5460.741
#     patch movingObject y+ : min = 5480.486, max = 7262.295, average = 6126.688
#
# Time = 0.0155
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 369.0179, max = 5463.023, average = 1132.999
#     patch bottom_1 y+ : min = 5460.255, max = 5923.196, average = 5493.58
#     patch right_3 y+ : min = 369.0179, max = 5463.023, average = 1132.999
#     patch bottom_3 y+ : min = 5460.255, max = 5923.239, average = 5493.583
#     patch left_4 y+ : min = 5460.183, max = 6859.805, average = 5672.571
#     patch right_4 y+ : min = 5460.183, max = 6859.722, average = 5672.567
#     patch bottom_4 y+ : min = 5460.183, max = 5460.267, average = 5460.191
#     patch movingObject y+ : min = 5479.079, max = 7264.823, average = 6148.281
#
# Time = 0.016
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 368.9811, max = 5462.58, average = 1132.898
#     patch bottom_1 y+ : min = 5459.695, max = 5934.735, average = 5493.937
#     patch right_3 y+ : min = 368.9811, max = 5462.581, average = 1132.898
#     patch bottom_3 y+ : min = 5459.695, max = 5934.778, average = 5493.94
#     patch left_4 y+ : min = 5459.632, max = 6876.682, average = 5678.964
#     patch right_4 y+ : min = 5459.632, max = 6876.597, average = 5678.96
#     patch bottom_4 y+ : min = 5459.632, max = 5459.722, average = 5459.641
#     patch movingObject y+ : min = 5477.606, max = 7264.641, average = 6169.904
#
# Time = 0.0165
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 368.9442, max = 5462.138, average = 1132.798
#     patch bottom_1 y+ : min = 5459.135, max = 5945.866, average = 5494.27
#     patch right_3 y+ : min = 368.9442, max = 5462.139, average = 1132.798
#     patch bottom_3 y+ : min = 5459.135, max = 5945.909, average = 5494.274
#     patch left_4 y+ : min = 5459.082, max = 6890.892, average = 5685.343
#     patch right_4 y+ : min = 5459.082, max = 6890.805, average = 5685.338
#     patch bottom_4 y+ : min = 5459.082, max = 5459.177, average = 5459.091
#     patch movingObject y+ : min = 5476.083, max = 7262.429, average = 6191.541
#
# Time = 0.017
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
# ...
#
# Time = 0.4945
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 345.8799, max = 5064.845, average = 1053.873
#     patch bottom_1 y+ : min = 4634.705, max = 66068.62, average = 6962.072
#     patch right_3 y+ : min = 345.7175, max = 5064.681, average = 1053.413
#     patch bottom_3 y+ : min = 4635.95, max = 66102.06, average = 6966.159
#     patch left_4 y+ : min = 4248.219, max = 333728.8, average = 85417.39
#     patch right_4 y+ : min = 4248.217, max = 333789.3, average = 85424.36
#     patch bottom_4 y+ : min = 4963.37, max = 4983.16, average = 4965.38
#     patch movingObject y+ : min = 5126.545, max = 430944.2, average = 158410.5
#
# Time = 0.495
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 345.8621, max = 5064.474, average = 1053.815
#     patch bottom_1 y+ : min = 4635.179, max = 65701.19, average = 6952.982
#     patch right_3 y+ : min = 345.7001, max = 5064.31, average = 1053.366
#     patch bottom_3 y+ : min = 4636.467, max = 65733.76, average = 6957.041
#     patch left_4 y+ : min = 4247.036, max = 334464.7, average = 85599.96
#     patch right_4 y+ : min = 4247.033, max = 334529.3, average = 85607.34
#     patch bottom_4 y+ : min = 4962.893, max = 4982.705, average = 4964.905
#     patch movingObject y+ : min = 5128.689, max = 432278, average = 159443
#
# Time = 0.4955
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 345.8444, max = 5064.104, average = 1053.761
#     patch bottom_1 y+ : min = 4635.729, max = 65335.82, average = 6943.856
#     patch right_3 y+ : min = 345.6821, max = 5063.939, average = 1053.314
#     patch bottom_3 y+ : min = 4637.06, max = 65367.47, average = 6947.885
#     patch left_4 y+ : min = 4245.854, max = 335023, average = 85774.21
#     patch right_4 y+ : min = 4245.852, max = 335091.9, average = 85782.01
#     patch bottom_4 y+ : min = 4962.416, max = 4982.25, average = 4964.431
#     patch movingObject y+ : min = 5130.845, max = 433538.3, average = 160470.3
#
# Time = 0.496
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 345.8266, max = 5063.734, average = 1053.711
#     patch bottom_1 y+ : min = 4636.313, max = 64982.22, average = 6934.948
#     patch right_3 y+ : min = 345.6639, max = 5063.569, average = 1053.258
#     patch bottom_3 y+ : min = 4637.688, max = 65012.96, average = 6938.947
#     patch left_4 y+ : min = 4244.674, max = 335409.7, average = 85942.31
#     patch right_4 y+ : min = 4244.672, max = 335482.8, average = 85950.54
#     patch bottom_4 y+ : min = 4961.94, max = 4981.795, average = 4963.957
#     patch movingObject y+ : min = 5133.003, max = 434756.5, average = 161496.9
#
# Time = 0.4965
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 345.8088, max = 5063.364, average = 1053.659
#     patch bottom_1 y+ : min = 4636.927, max = 64642.17, average = 6926.309
#     patch right_3 y+ : min = 345.6457, max = 5063.198, average = 1053.198
#     patch bottom_3 y+ : min = 4638.344, max = 64672, average = 6930.276
#     patch left_4 y+ : min = 4243.495, max = 335635.7, average = 86104.89
#     patch right_4 y+ : min = 4243.493, max = 335713, average = 86113.57
#     patch bottom_4 y+ : min = 4961.463, max = 4981.341, average = 4963.482
#     patch movingObject y+ : min = 5135.157, max = 435937, average = 162523
#
# Time = 0.497
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 345.7908, max = 5062.995, average = 1053.603
#     patch bottom_1 y+ : min = 4637.564, max = 64316.72, average = 6917.97
#     patch right_3 y+ : min = 345.6273, max = 5062.829, average = 1053.133
#     patch bottom_3 y+ : min = 4639.024, max = 64345.65, average = 6921.906
#     patch left_4 y+ : min = 4242.318, max = 335717.4, average = 86262.51
#     patch right_4 y+ : min = 4242.316, max = 335798.6, average = 86271.65
#     patch bottom_4 y+ : min = 4960.987, max = 4980.886, average = 4963.008
#     patch movingObject y+ : min = 5137.312, max = 437081.8, average = 163548.1
#
# Time = 0.4975
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 345.7728, max = 5062.626, average = 1053.543
#     patch bottom_1 y+ : min = 4638.216, max = 64007.28, average = 6909.975
#     patch right_3 y+ : min = 345.6093, max = 5062.459, average = 1053.072
#     patch bottom_3 y+ : min = 4639.718, max = 64035.4, average = 6913.879
#     patch left_4 y+ : min = 4241.142, max = 335673.9, average = 86415.81
#     patch right_4 y+ : min = 4241.141, max = 335758.8, average = 86425.43
#     patch bottom_4 y+ : min = 4960.511, max = 4980.432, average = 4962.534
#     patch movingObject y+ : min = 5139.425, max = 438193.9, average = 164571.8
#
# Time = 0.498
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 345.7547, max = 5062.256, average = 1053.483
#     patch bottom_1 y+ : min = 4638.869, max = 63715.84, average = 6902.38
#     patch right_3 y+ : min = 345.5916, max = 5062.089, average = 1053.024
#     patch bottom_3 y+ : min = 4640.414, max = 63743.21, average = 6906.253
#     patch left_4 y+ : min = 4239.969, max = 335527.3, average = 86565.51
#     patch right_4 y+ : min = 4239.967, max = 335615.7, average = 86575.63
#     patch bottom_4 y+ : min = 4960.034, max = 4979.977, average = 4962.06
#     patch movingObject y+ : min = 5141.492, max = 439277.3, average = 165594.2
#
# Time = 0.4985
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 345.736, max = 5061.885, average = 1053.413
#     patch bottom_1 y+ : min = 4639.248, max = 64400.97, average = 6919.267
#     patch right_3 y+ : min = 345.5731, max = 5061.718, average = 1052.963
#     patch bottom_3 y+ : min = 4640.834, max = 64429.43, average = 6923.154
#     patch left_4 y+ : min = 4238.796, max = 335317, average = 86719.18
#     patch right_4 y+ : min = 4238.795, max = 335408.6, average = 86729.81
#     patch bottom_4 y+ : min = 4959.558, max = 4979.523, average = 4961.587
#     patch movingObject y+ : min = 5143.597, max = 440380.4, average = 166638
#
# Time = 0.499
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 345.7173, max = 5061.513, average = 1053.341
#     patch bottom_1 y+ : min = 4639.447, max = 65629.78, average = 6949.841
#     patch right_3 y+ : min = 345.5541, max = 5061.345, average = 1052.891
#     patch bottom_3 y+ : min = 4641.071, max = 65659.58, average = 6953.745
#     patch left_4 y+ : min = 4237.625, max = 335062.9, average = 86875.89
#     patch right_4 y+ : min = 4237.624, max = 335157.5, average = 86887.06
#     patch bottom_4 y+ : min = 4959.082, max = 4979.069, average = 4961.113
#     patch movingObject y+ : min = 5145.784, max = 441475.5, average = 167694.1
#
# Time = 0.4995
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 345.6984, max = 5061.14, average = 1053.258
#     patch bottom_1 y+ : min = 4639.594, max = 66969.9, average = 6983.261
#     patch right_3 y+ : min = 345.5349, max = 5060.971, average = 1052.805
#     patch bottom_3 y+ : min = 4641.259, max = 67000.87, average = 6987.179
#     patch left_4 y+ : min = 4236.456, max = 334788.3, average = 87033.56
#     patch right_4 y+ : min = 4236.455, max = 334885.7, average = 87045.29
#     patch bottom_4 y+ : min = 4958.606, max = 4978.615, average = 4960.639
#     patch movingObject y+ : min = 5147.986, max = 442538.8, average = 168748.1
#
# Time = 0.5
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 345.6795, max = 5060.768, average = 1053.171
#     patch bottom_1 y+ : min = 4639.748, max = 68273.48, average = 7015.809
#     patch right_3 y+ : min = 345.5158, max = 5060.598, average = 1052.716
#     patch bottom_3 y+ : min = 4641.452, max = 68305.61, average = 7019.739
#     patch left_4 y+ : min = 4235.288, max = 334505.4, average = 87190.9
#     patch right_4 y+ : min = 4235.287, max = 334605.7, average = 87203.22
#     patch bottom_4 y+ : min = 4958.131, max = 4978.161, average = 4960.166
#     patch movingObject y+ : min = 5150.202, max = 443605.9, average = 169804.6
#
# End
#
# Finalising parallel run

# %%
import re
import pandas as pd
import matplotlib.pyplot as plt

# Define file path
log_yPlus_path = "log.yPlus"  # Update with your actual path

# Read log file
with open(log_yPlus_path, 'r') as file:
    log_data = file.readlines()

# Extract time and yPlus values for different patches
time_steps = []
patch_data = {}
current_time = None

patch_pattern = re.compile(r'patch (\S+) y\+ : min = ([\d\.]+), max = ([\d\.]+), average = ([\d\.]+)')

for line in log_data:
    time_match = re.match(r"Time = ([0-9.eE+-]+)", line)
    if time_match:
        current_time = float(time_match.group(1))
        if current_time not in time_steps:
            time_steps.append(current_time)
    else:
        patch_match = patch_pattern.search(line)
        if patch_match and current_time is not None:
            patch_name = patch_match.group(1)
            yplus_avg = float(patch_match.group(4))
            
            if patch_name not in patch_data:
                patch_data[patch_name] = []
            patch_data[patch_name].append((current_time, yplus_avg))

# Convert to DataFrame
df_list = []
for patch, values in patch_data.items():
    df = pd.DataFrame(values, columns=["Time", "yPlus"])
    df["Patch"] = patch
    df_list.append(df)

df_yplus = pd.concat(df_list, ignore_index=True)

# Save to CSV
df_yplus.to_csv("yPlus_data.csv", index=False)
print("yPlus data saved to yPlus_data.csv")

# Plot yPlus values over time for each patch
plt.figure(figsize=(10, 6))
for patch in patch_data:
    df_patch = df_yplus[df_yplus["Patch"] == patch]
    plt.plot(df_patch["Time"], df_patch["yPlus"], label=patch)

plt.xlabel("Time")
plt.ylabel("yPlus Average")
plt.title("yPlus Evolution Over Time for Different Patches")
plt.legend()
plt.grid(True)

# Show plot
plt.show()
# Out:
# yPlus data saved to yPlus_data.csv

# %%
import matplotlib.pyplot as plt

# Plot the extracted values
plt.figure(figsize=(10, 6))

plt.scatter(range(len(nCells_values)), nCells_values, label='nCells', marker='.')
plt.xlabel('Index')
plt.ylabel('Values')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Plot the extracted values
plt.figure(figsize=(10, 6))

plt.plot(calculated_values, label='Calculated Values', marker='.')
plt.xlabel('Index')
plt.ylabel('Values')
plt.legend()
plt.grid(True)
plt.show()
print("Max calculated value:", max(calculated_values))
print("Min calculated value:", min(calculated_values))
#save the plot at folder /images/dynamicMovementsCalculated.png
plt.savefig('analysis/dynamicMovementsCalculated.png')
plt.close()
# Out:
# Max calculated value: 11464.0
# Min calculated value: 11464.0

# %%
# Plot the extracted values
plt.figure(figsize=(10, 6))

plt.plot(interpolated_values, label='Interpolated Values', marker='.')
plt.xlabel('Index')
plt.ylabel('Values')
plt.legend()
plt.grid(True)
plt.show()
print("Max calculated value:", max(interpolated_values))
print("Min calculated value:", min(interpolated_values))
#save the plot at folder /images/dynamicMovementsInterpolated.png
plt.savefig('analysis/dynamicMovementsInterpolated.png')
# Out:
# Max calculated value: 256.0
# Min calculated value: 256.0

# %%
# Plot the extracted values
plt.figure(figsize=(10, 6))

plt.plot(hole_values, label='Hole Values', marker='.')
plt.xlabel('Index')
plt.ylabel('Values')
plt.legend()
plt.grid(True)
plt.show()
# show max and min values
print("Max calculated value:", max(hole_values))
print("Min calculated value:", min(hole_values))
#save the plot at folder /images/dynamicMovementsHoles.png
plt.savefig('analysis/dynamicMovementsHoles.png')
# Out:
# Max calculated value: 658.0
# Min calculated value: 658.0
